# %%
import sys
# !{sys.executable} -m pip install 'gym[all]'
# !{sys.executable} -m pip install 'numpy'
# !{sys.executable} -m pip install 'tensorflow'
# !{sys.executable} -m pip install 'tensorflow-gpu'
# !{sys.executable} -m pip install 'opencv-python'
# !{sys.executable} -m pip install 'matplotlib'
# !{sys.executable} -m pip install 'tensorboardx'
# !{sys.executable} -m pip install 'pandas'
# !{sys.executable} -m pip install 'box2d-py'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gym[all]
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      |████████████████████████████████| 721 kB 833 kB/s eta 0:00:01
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-build-env-aqn_hm6a/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-build-env-aqn_hm6a/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-build-env-aqn_hm6a/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-build-env-aqn_hm6a/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-build-env-aqn_hm6a/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-build-env-aqn_hm6a/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy>=1.18.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from gym[all]) (1.24.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from gym[all]) (6.0.0)
# Collecting gym-notices>=0.0.4
#   Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Collecting cloudpickle>=1.2.0
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting lz4>=3.1.0
#   Downloading lz4-4.3.2-cp39-cp39-macosx_11_0_arm64.whl (212 kB)
#      |████████████████████████████████| 212 kB 10.6 MB/s eta 0:00:01
# Collecting box2d-py==2.3.5
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      |████████████████████████████████| 374 kB 39.9 MB/s eta 0:00:01
# Collecting mujoco-py<2.2,>=2.1
#   Downloading mujoco_py-2.1.2.14-py3-none-any.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 16.4 MB/s eta 0:00:01
# Collecting imageio>=2.14.1
#   Downloading imageio-2.31.5-py3-none-any.whl (313 kB)
#      |████████████████████████████████| 313 kB 1.6 MB/s eta 0:00:01
# Collecting opencv-python>=3.0
#   Downloading opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
#      |████████████████████████████████| 33.1 MB 461 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=3.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from gym[all]) (3.8.0)
# Collecting swig==4.*
#   Downloading swig-4.1.1-py2.py3-none-macosx_11_0_arm64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 668 kB/s eta 0:00:01
# Collecting ale-py~=0.8.0
#   Downloading ale_py-0.8.1-cp39-cp39-macosx_11_0_arm64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 1.1 MB/s eta 0:00:01
# Collecting pygame==2.1.0
#   Downloading pygame-2.1.0-cp39-cp39-macosx_11_0_arm64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 1.3 MB/s eta 0:00:01
# Collecting moviepy>=1.0.0
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      |████████████████████████████████| 388 kB 1.4 MB/s eta 0:00:01
# Collecting mujoco==2.2
#   Downloading mujoco-2.2.0-cp39-cp39-macosx_11_0_arm64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 702 kB/s eta 0:00:01
# Collecting pytest==7.0.1
#   Downloading pytest-7.0.1-py3-none-any.whl (296 kB)
#      |████████████████████████████████| 296 kB 1.3 MB/s eta 0:00:01
# Collecting absl-py
#   Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 1.4 MB/s eta 0:00:01
# Collecting glfw
#   Downloading glfw-2.6.2-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-macosx_11_0_arm64.whl (92 kB)
#      |████████████████████████████████| 92 kB 1.2 MB/s eta 0:00:01
# Collecting pyopengl
#   Downloading PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 921 kB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from pytest==7.0.1->gym[all]) (23.0)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: attrs>=19.2.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from pytest==7.0.1->gym[all]) (22.2.0)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.3.0-py3-none-any.whl (18 kB)
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 669 kB/s eta 0:00:01
# Requirement already satisfied: importlib-resources in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from ale-py~=0.8.0->gym[all]) (6.1.0)
# Collecting typing-extensions
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: pillow>=8.3.2 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from imageio>=2.14.1->gym[all]) (10.0.1)
# Requirement already satisfied: zipp>=0.5 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gym[all]) (3.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gym[all]) (1.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gym[all]) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gym[all]) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gym[all]) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gym[all]) (4.43.1)
# Requirement already satisfied: cycler>=0.10 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gym[all]) (0.12.1)
# Collecting decorator<5.0,>=4.0.2
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from moviepy>=1.0.0->gym[all]) (4.66.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from moviepy>=1.0.0->gym[all]) (2.31.0)
# Collecting proglog<=1.0.0
#   Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading imageio-ffmpeg-0.4.9.tar.gz (17 kB)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from imageio_ffmpeg>=0.2.0->moviepy>=1.0.0->gym[all]) (58.0.4)
# Requirement already satisfied: cffi>=1.10 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from mujoco-py<2.2,>=2.1->gym[all]) (1.15.1)
# Collecting fasteners~=0.15
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Collecting Cython>=0.27.2
#   Downloading Cython-3.0.3-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 424 kB/s eta 0:00:01
# Requirement already satisfied: pycparser in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1->gym[all]) (2.21)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gym[all]) (1.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gym[all]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gym[all]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gym[all]) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gym[all]) (2.0.6)
# Building wheels for collected packages: box2d-py, moviepy, imageio-ffmpeg, gym
#   Building wheel for box2d-py (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-o3aua9pk/box2d-py_bc7bf53c9408445ba42e76c933872cc8/setup.py'"'"'; __file__='"'"'/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-o3aua9pk/box2d-py_bc7bf53c9408445ba42e76c933872cc8/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-wheel-d7riy_ug
#        cwd: /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-o3aua9pk/box2d-py_bc7bf53c9408445ba42e76c933872cc8/
#   Complete output (16 lines):
#   Using setuptools (version 58.0.4).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-universal2-3.9
#   creating build/lib.macosx-10.9-universal2-3.9/Box2D
#   copying library/Box2D/Box2D.py -> build/lib.macosx-10.9-universal2-3.9/Box2D
#   copying library/Box2D/__init__.py -> build/lib.macosx-10.9-universal2-3.9/Box2D
#   creating build/lib.macosx-10.9-universal2-3.9/Box2D/b2
#   copying library/Box2D/b2/__init__.py -> build/lib.macosx-10.9-universal2-3.9/Box2D/b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
#   swig -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library/Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D/Box2D_wrap.cpp Box2D/Box2D.i
#   error: command 'swig' failed: No such file or directory
#   ----------------------------------------
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110744 sha256=9af55f0fa4f599dec4ac61282664fcad9b389675e96941abae2689b29476622b
#   Stored in directory: /Users/michaeltomadakis/Library/Caches/pip/wheels/29/15/e4/4f790bec6acd51a00b67e8ee1394f0bc6e0135c315f8ff399a
#   Building wheel for imageio-ffmpeg (setup.py) ... done
#   Created wheel for imageio-ffmpeg: filename=imageio_ffmpeg-0.4.9-py3-none-any.whl size=16372 sha256=eb8fbadf08929f6110229c3ac4c444b50555d49bbaa76d2c310d8f8d09b8fa50
#   Stored in directory: /Users/michaeltomadakis/Library/Caches/pip/wheels/a0/a2/a5/801b8c9041c8149b486509ade5eb48e3c474d17d31f3746860
#   Building wheel for gym (PEP 517) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827649 sha256=42e5546a4e1274703167e19509c75be24361e5a389aa75ea2a1a97dcf7d27ad8
#   Stored in directory: /Users/michaeltomadakis/Library/Caches/pip/wheels/af/2b/30/5e78b8b9599f2a2286a582b8da80594f654bf0e18d825a4405
# Successfully built moviepy imageio-ffmpeg gym
# Failed to build box2d-py
# Installing collected packages: typing-extensions, tomli, pyopengl, py, proglog, pluggy, iniconfig, imageio-ffmpeg, imageio, gym-notices, glfw, fasteners, decorator, Cython, cloudpickle, absl-py, swig, pytest, pygame, opencv-python, mujoco-py, mujoco, moviepy, lz4, gym, box2d-py, ale-py
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
#     Running setup.py install for box2d-py ... done
#   DEPRECATION: box2d-py was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.
# Successfully installed Cython-3.0.3 absl-py-2.0.0 ale-py-0.8.1 box2d-py-2.3.5 cloudpickle-2.2.1 decorator-4.4.2 fasteners-0.19 glfw-2.6.2 gym-0.26.2 gym-notices-0.0.8 imageio-2.31.5 imageio-ffmpeg-0.4.9 iniconfig-2.0.0 lz4-4.3.2 moviepy-1.0.3 mujoco-2.2.0 mujoco-py-2.1.2.14 opencv-python-4.8.1.78 pluggy-1.3.0 proglog-0.1.10 py-1.11.0 pygame-2.1.0 pyopengl-3.1.7 pytest-7.0.1 swig-4.1.1 tomli-2.0.1 typing-extensions-4.8.0
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (1.24.4)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.14.0-cp39-cp39-macosx_12_0_arm64.whl (2.1 kB)
# Collecting tensorflow-macos==2.14.0
#   Downloading tensorflow_macos-2.14.0-cp39-cp39-macosx_12_0_arm64.whl (199.7 MB)
#      |█████████▍                      | 58.3 MB 381 kB/s eta 0:06:11^C
#
# ERROR: Operation cancelled by user
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
# Collecting python_version>"3.7"
#   Downloading python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/setup.py'"'"'; __file__='"'"'/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-wheel-k758wpwh
#        cwd: /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/
#   Complete output (17 lines):
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   ----------------------------------------
#   ERROR: Failed building wheel for tensorflow-gpu
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: python-version, tensorflow-gpu
#     Running setup.py install for tensorflow-gpu ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/setup.py'"'"'; __file__='"'"'/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-record-y8a3dnn4/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /Users/michaeltomadakis/Library/Python/3.9/include/python3.9/tensorflow-gpu
#          cwd: /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/
#     Complete output (17 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/setup.py", line 37, in <module>
#         raise Exception(TF_REMOVAL_WARNING)
#     Exception:
#
#     =========================================================
#     The "tensorflow-gpu" package has been removed!
#
#     Please install "tensorflow" instead.
#
#     Other than the name, the two packages have been identical
#     since TensorFlow 2.1, or roughly since Sep 2019. For more
#     information, see: pypi.org/project/tensorflow-gpu
#     =========================================================
#
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Library/Developer/CommandLineTools/usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/setup.py'"'"'; __file__='"'"'/private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-install-w2w6s7kp/tensorflow-gpu_c9776259b7554d78a7f212c1909bd9d2/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/6k/l6s17crs07jgzxv4jh2fy2g40000gn/T/pip-record-y8a3dnn4/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /Users/michaeltomadakis/Library/Python/3.9/include/python3.9/tensorflow-gpu Check the logs for full command output.
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.17.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from opencv-python) (1.24.4)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (3.8.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: cycler>=0.10 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.13.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorboardx
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 1.5 MB/s ta 0:00:01
# Requirement already satisfied: numpy in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from tensorboardx) (1.24.4)
# Collecting protobuf>=3.20
#   Downloading protobuf-4.24.4-cp37-abi3-macosx_10_9_universal2.whl (409 kB)
#      |████████████████████████████████| 409 kB 5.2 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from tensorboardx) (23.0)
# Installing collected packages: protobuf, tensorboardx
# Successfully installed protobuf-4.24.4 tensorboardx-2.6.2.2
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: box2d-py in /Users/michaeltomadakis/Library/Python/3.9/lib/python/site-packages (2.3.5)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
